# %% [markdown]
# Print Hello World

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Greet Function

# %%
def greet(name):
  print("My name is : " ,name)

string=input("Enter a name : ")
greet(string)
# Out:
# My name is :  Bhavesh

# %% [markdown]
# Squred The list

# %%
list=[1,2,3,4,5]
print(list)

squred_no=[num*num for num in list]
print(squred_no)
# Out:
# [1, 2, 3, 4, 5]
# [1, 4, 9, 16, 25]

# %% [markdown]
# Greet Names

# %%
def greet_names(names):
  greeted_names=[f"Hello {name}" for name in names]
  return greeted_names

name=["Bhavesh","Khushi","Palak","Jay","Krishna" ,"Varunn","Manish"]
print(greet_names(name))
# Out:
# ['Hello Bhavesh', 'Hello Khushi', 'Hello Palak', 'Hello Jay', 'Hello Krishna', 'Hello Varunn', 'Hello Manish']

# %% [markdown]
# Example To Import Pandas and Numpy Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

iris=load_iris()
x=iris.data
y=iris.target
print("Iris dataset loaded . Feature shape : ",x.shape)
df=pd.DataFrame(x,columns=iris.feature_names)
df.info()
df.describe()
print(df.head())
# Out:
# Iris dataset loaded . Feature shape :  (150, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
import pyttsx3 
#pyttsx3.speak("Hello My name is Thushiiiiii. Student of Techno India NJR.")
import datetime
d=datetime.datetime.now().hour
pyttsx3.speak(f"time is {d}")
from datetime import * 
print(f"{datetime.now()}")
# Out:
# 2025-04-12 14:53:25.736357

# %%
import pyttsx3
ram=pyttsx3.init('sapi5') #Speak application program interface version 5
x=ram.getProperty('voices')
print (x)
print(x[0].id , x[1].id, x[2].id)
ch=int(input("enter your choice : "))
if(ch==1):
    ram.setProperty('voice',x[1].id)
elif(ch==0):
    ram.setProperty('voice',x[0].id)

def bolo(audio):
    ram.say(audio)
    ram.runAndWait()
bolo("Hello bhavesh.")
# Out:
# [<pyttsx3.voice.Voice object at 0x000002072133E630>, <pyttsx3.voice.Voice object at 0x000002072112C6E0>, <pyttsx3.voice.Voice object at 0x00000207212E7830>]
# HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_DAVID_11.0 HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-GB_HAZEL_11.0 HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       4 print (x)
#       5 print(x[0].id , x[1].id, x[2].id)
# ----> 6 ch=int(input("enter your choice : "))
#       7 if(ch==1):
#       8     ram.setProperty('voice',x[1].id)
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %%
import wikipedia
import pyttsx3
pyttsx3.speak("What do you want to search : ")
d = input("What you want to search : ")
ans=wikipedia.summary(d,sentences=3)
print(ans)
pyttsx3.speak(ans)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ...

# %%
#from deep_translator import GoogleTranslator
#result=GoogleTranslator (source='auto' , target='hi').translate(text="Hello, how are you?")
#print(result)
#pyttsx3.speak(result)
